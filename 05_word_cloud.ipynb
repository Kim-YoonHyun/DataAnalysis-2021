# %% [markdown]
# # word cloud

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
from PIL import Image
import numpy as np

# %% [markdown]
# ## 1. Alice in wonderland

# %%
from google.colab import files
uploaded = files.upload()
maskfile = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-6180d3a6-fd87-4d30-9e0e-a190a965a869" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6180d3a6-fd87-4d30-9e0e-a190a965a869">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Alice_mask.png to Alice_mask.png

# %%
uploaded = files.upload()
text_file = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-28746bab-8942-4167-a6f3-b9c7d157b42b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-28746bab-8942-4167-a6f3-b9c7d157b42b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Alice.txt to Alice.txt

# %%
with open(text_file) as fp:
  text = fp.read()

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
stop_words.add('said')

# %%
wc = WordCloud(background_color='white',
               max_words=1000, stopwords=stop_words)
wc.generate(text)

# %%
type(wc.words_)
# Out:
# dict

# %%
keys = list(wc.words_.keys())
values = list(wc.words_.values())
for i in range(10):
  print(keys[i], ':', values[i])
# Out:
# Alice : 1.0
# little : 0.2958904109589041
# one : 0.2602739726027397
# know : 0.2465753424657534
# like : 0.2356164383561644
# would : 0.2273972602739726
# went : 0.2273972602739726
# thing : 0.2191780821917808
# could : 0.21095890410958903
# time : 0.21095890410958903

# %%
plt.figure(figsize=(10,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
mask = np.array(Image.open(maskfile))
plt.imshow(mask, cmap=plt.cmgray, imterpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-6a87f36dd1c9> in <module>()
#       1 mask = np.array(Image.open(maskfile))
# ----> 2 plt.imshow(mask, cmap=plt.cmgray, imterpolation='bilinear')
#       3 plt.axis('off')
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'cmgray'

# %%
wc.Wordcloud(back)

# %%
plt.figure

# %% [markdown]
# ## 2. Star Wars

# %%
from google.colab import files
uploaded = files.upload()
textfile = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-6bd6d5c2-ce14-4952-b299-bd060275e3ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6bd6d5c2-ce14-4952-b299-bd060275e3ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving A_new_hope.txt to A_new_hope.txt

# %%
uploaded = files.upload()
maskfile = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-26abaa8f-3803-4279-9df4-6f2c774141ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26abaa8f-3803-4279-9df4-6f2c774141ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Stormtrooper_mask.png to Stormtrooper_mask.png

# %%
text = text.replace('HAM', 'Han')
text = text.replace("LUKE's", "Luke")

# %%
from wordcloud import STOPWORDS
stop_words = set(STOPWORDS)
stop_words.add('int')
stop_words.add('ext')
len(stop_words)
# Out:
# 192

# %%
wc = WordCloud(mask=mask,
               max_words=1000, stopwords=stop_words,
               margin=10, random_state=2021)
wc.generate(text)
default_colors = wc.to_array

# %%
import random
def grey_color(word, font_size, position,
               orientation, random_state=None, **kwargs):
  # return 'hsl(0, 0%%, %d%%)' % random.randint(60, 100)
  # hue, saturation, lightness
  return f'hsl(0, 0%, {random.randint(60, 100)}%)'

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=grey_color, random_state=2021),
           interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-cc686b81fd24> in <module>()
#       1 plt.figure(figsize=(12,12))
#       2 plt.imshow(wc.recolor(color_func=grey_color, random_state=2021),
# ----> 3            interpolation='bilinear')
#       4 plt.axis('off')
#       5 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5624                               resample=resample, **kwargs)
#    5625
# -> 5626         im.set_data(X)
#    5627         im.set_alpha(alpha)
#    5628         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in set_data(self, A)
#     687             if isinstance(A, Image.Image):
#     688                 A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 689         self._A = cbook.safe_masked_invalid(A, copy=True)
#     690
#     691         if (self._A.dtype != np.uint8 and
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in safe_masked_invalid(x, copy)
#     704
#     705 def safe_masked_invalid(x, copy=False):
# --> 706     x = np.array(x, subok=True, copy=copy)
#     707     if not x.dtype.isnative:
#     708         # Note that the argument to `byteswap` is 'inplace',
#
# /usr/local/lib/python3.7/dist-packages/wordcloud/wordcloud.py in __array__(self)
#     711             Word cloud image as numpy matrix.
#     712         """
# --> 713         return self.to_array()
#     714
#     715     def to_html(self):
#
# /usr/local/lib/python3.7/dist-packages/wordcloud/wordcloud.py in to_array(self)
#     701             Word cloud image as numpy matrix.
#     702         """
# --> 703         return np.array(self.to_image())
#     704
#     705     def __array__(self):
#
# /usr/local/lib/python3.7/dist-packages/wordcloud/wordcloud.py in to_image(self)
#     630             pos = (int(position[1] * self.scale),
#     631                    int(position[0] * self.scale))
# --> 632             draw.text(pos, word, fill=color, font=transposed_font)
#     633
#     634         return self._draw_contour(img=img)
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageDraw.py in text(self, xy, text, fill, font, anchor, spacing, align, direction, features, language, stroke_width, stroke_fill, *args, **kwargs)
#     335             self.draw.draw_bitmap(coord, mask, ink)
#     336
# --> 337         ink = getink(fill)
#     338         if ink is not None:
#     339             stroke_ink = None
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageDraw.py in getink(fill)
#     298
#     299         def getink(fill):
# --> 300             ink, fill = self._getink(fill)
#     301             if ink is None:
#     302                 return fill
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageDraw.py in _getink(self, ink, fill)
#     108             if ink is not None:
#     109                 if isinstance(ink, str):
# --> 110                     ink = ImageColor.getcolor(ink, self.mode)
#     111                 if self.palette and not isinstance(ink, numbers.Number):
#     112                     ink = self.palette.getcolor(ink)
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageColor.py in getcolor(color, mode)
#     129     """
#     130     # same as getrgb, but converts the result to the given mode
# --> 131     color, alpha = getrgb(color), 255
#     132     if len(color) == 4:
#     133         color, alpha = color[0:3], color[3]
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageColor.py in getrgb(color)
#     114     if m:
#     115         return (int(m.group(1)), int(m.group(2)), int(m.group(3)), int(m.group(4)))
# --> 116     raise ValueError("unknown color specifier: %r" % color)
#     117
#     118
#
# ValueError: unknown color specifier: 'hsl(0, 0%, 64%'
